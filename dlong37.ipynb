# %% [markdown]
# # Assigned GitHub Projects
#
# **NOTE:** Information recorded as of September 22, 2026
#
# 1. https://github.com/delftdata/valentine
#     * 126 Stars
#     * 26 Forks
#     * Last Commit on July 26, 2026
#     * 493 Commits
#     * 27 Authors
#     * Min Time: 1561729814
#     * Max Time: 1760442339
# 2. https://github.com/darioizzo/geodesyNets
#     * 20 Stars
#     * 5 Forks
#     * Last Commit on September 16, 2025
#     * 368 Commits
#     * 7 Authors
#     * Min Time: 1600337492
#     * Max Time: 1758027483
# 3. https://github.com/Antonio-JP/dd_functions
#     * 4 Stars
#     * 3 Forks
#     * Last Commit on March 3, 2022
#     * 484 Commits
#     * 12 Authors
#     * Min Time: 1520505564
#     * Max Time: 1749739260
# 4. https://github.com/ANYbotics/elevation_mapping
#     * 1.9K Stars
#     * 507 Forks
#     * Last Commit on November 4, 2024
#     * 745 Commits
#     * 87 Authors
#     * Min Time: 1385453472
#     * Max Time: 1753933410
# 5. https://github.com/singmann/afex
#     * 131 Stars
#     * 30 Forks
#     * Last Commit on December 14, 2025
#     * 711 Commits
#     * 22 Authors
#     * Min Time: 1435608057
#     * Max Time: 1756241804
# 6. https://github.com/opensafely/antibody-and-antiviral-deployment
#     * 1 Star
#     * 4 Forks
#     * Last Commit on February 13, 2024
#     * 519 Commits
#     * 14 Authors
#     * Min Time: 1641313155
#     * Max Time: 1730894499
# 7. https://github.com/sebmart/TaxiSimulation
#     * 17 Stars
#     * 11 Forks
#     * Last Commit on November 14, 2024
#     * 588 Commits
#     * 6 Authors
#     * Min Time: 1432573855
#     * Max Time: 1731600175
# 8. https://github.com/brainstorm-tools/brainstorm3
#     * 487 Stars
#     * 190 Forks
#     * Last Commit on September 15, 2026
#     * 7833 Commits
#     * 122 Authors
#     * Min Time: 1477005850
#     * Max Time: 1762292977
# 9. https://github.com/langurmonkey/gaiasky
#     * 13 Stars
#     * 1 Fork
#     * Last Commit on September 22, 2026
#     * 8552 Commits
#     * 33 Authors
#     * Min Time: 1418309310
#     * Max Time: 1762350620
# 10. https://github.com/jump-dev/SumOfSquares.jl
#     * 131 Stars
#     * 26 Forks
#     * Last Commit on September 21, 2026
#     * 2079 Commits
#     * 37 Authors
#     * Min Time: 1470927779
#     * Max Time: 1776253611

# %% [markdown]
# # Code
# Please refer to dlong37_vis.ipynb for how I collected the number of commits, number of authors, min time, and max time for each project.
