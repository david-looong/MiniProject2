# %% [markdown]
# # Assigned GitHub Projects
#
# **NOTE:** Information recorded as of September 22, 2026
#
# 1. https://github.com/delftdata/valentine
#     * 126 Stars
#     * 26 Forks
#     * Last Commit on July 26, 2026
#     * 493 Commits
#     * 27 Authors
#     * Min Time: 1561729814
#     * Max Time: 1760442339
# 2. https://github.com/darioizzo/geodesyNets
#     * 20 Stars
#     * 5 Forks
#     * Last Commit on September 16, 2025
#     * 368 Commits
#     * 7 Authors
#     * Min Time: 1600337492
#     * Max Time: 1758027483
# 3. https://github.com/Antonio-JP/dd_functions
#     * 4 Stars
#     * 3 Forks
#     * Last Commit on March 3, 2022
#     * 484 Commits
#     * 12 Authors
#     * Min Time: 1520505564
#     * Max Time: 1749739260
# 4. https://github.com/ANYbotics/elevation_mapping
#     * 1.9K Stars
#     * 507 Forks
#     * Last Commit on November 4, 2024
#     * 745 Commits
#     * 87 Authors
#     * Min Time: 1385453472
#     * Max Time: 1753933410
# 5. https://github.com/singmann/afex
#     * 131 Stars
#     * 30 Forks
#     * Last Commit on December 14, 2025
#     * 711 Commits
#     * 22 Authors
#     * Min Time: 1435608057
#     * Max Time: 1756241804
# 6. https://github.com/opensafely/antibody-and-antiviral-deployment
#     * 1 Star
#     * 4 Forks
#     * Last Commit on February 13, 2024
#     * 519 Commits
#     * 14 Authors
#     * Min Time: 1641313155
#     * Max Time: 1730894499
# 7. https://github.com/sebmart/TaxiSimulation
#     * 17 Stars
#     * 11 Forks
#     * Last Commit on November 14, 2024
#     * 588 Commits
#     * 6 Authors
#     * Min Time: 1432573855
#     * Max Time: 1731600175
# 8. https://github.com/brainstorm-tools/brainstorm3
#     * 487 Stars
#     * 190 Forks
#     * Last Commit on September 15, 2026
#     * 7833 Commits
#     * 122 Authors
#     * Min Time: 1477005850
#     * Max Time: 1762292977
# 9. https://github.com/langurmonkey/gaiasky
#     * 13 Stars
#     * 1 Fork
#     * Last Commit on September 22, 2026
#     * 8552 Commits
#     * 33 Authors
#     * Min Time: 1418309310
#     * Max Time: 1762350620
# 10. https://github.com/jump-dev/SumOfSquares.jl
#     * 131 Stars
#     * 26 Forks
#     * Last Commit on September 21, 2026
#     * 2079 Commits
#     * 37 Authors
#     * Min Time: 1470927779
#     * Max Time: 1776253611

# %% [markdown]
# # Interpretation
#
# Trends:
#
# steady, rising, declining, U-shaped: Long-term, general movements in activity levels. An upward trend might indicate that a person is becoming more active over several months, while a downward trend could signal a decrease in mobility.
#
# Seasonal/Cyclical patterns: Predictable and repeated patterns of activity that occur at fixed intervals, such as quarterly or annually.
#
# Irregular or random variations: Unpredictable changes in activity that cannot be explained by trends or seasonal patterns.
#
# 1. **delftdata_valentine** - While there are a high amount of commits initially at the start, the number of commits is steadily around little to none for most of the commit history recorded. Number of three-month minimum gaps recorded was 3.
# 2. **darioizzo_geodesynets** - While there are a high amount of commits initially at the start, the number of commits is steadily around little to none for most of the commit history recorded. Number of three-month minimum gaps recorded was 4.
# 3. **antonio-jp_dd_functions** - There are some irregular spikes of high activity for this repo towards the middle of its commit history before completely flatlining for the backhalf up until fairly recently. Number of three-month minimum gaps recorded was 4.
# 4. **anybiotics_elevation_mapping** - Overall trends in this repo's commit history are slowly declining (despite the irregular spikes of activity) until they reach little to no commits for the repo. Number of three-month minimum gaps recorded was 3.
# 5. **singmann_afex** - There is a consistent trend of spikes in activity before dipping back to no activity for majority of this repo's commit history. Number of three-month minimum gaps recorded was 4.
# 6. **opensafely_antibody-and-antiviral-deployment** - Overall trend in this repo's commit history is slowly declining until they reach little to no commits for the repo. Number of three-month minimum gaps recorded was 2.
# 7. **sebmart_taxis** - Though there is steadily no activity for a good portion of this repo, there was a high amount of activity to start before slowly going towards that no activity time period. Number of three-month minimum gaps recorded was 4.
# 8. **brainstorm-tools_brainstorm3** - There is consistently spikes of high activity before dipping into less activity for majority of this repo's commit history. Number of three-month minimum gaps recorded was 0.
# 9. **langurmonkey_gaiasky** - The number of commits is steadily around the 0-100 mark for every month with only a couple of outliers present. Number of three-month minimum gaps recorded was 0.
# 10. **jump-dev_sumofsquares.jl** - While consistently cyclical for the first half, there is an irregular amount of activity with spikes in abnormally high activity relative to the first half of the repo history before dipping into zero activity. Number of three-month minimum gaps recorded was 2.
